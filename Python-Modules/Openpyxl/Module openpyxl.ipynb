# %% [markdown]
# # Module openpyxl

# %%
# Install the required module by executing this command in Command Prompt if using for the first time:
# pip install openpyxl

# %%
# openpyxl is a Python library to read/write Excel 2010 xlsx/xlsm/xltx/xltm files and format them.
# The documentation is available at: https://openpyxl.readthedocs.io

# %%
# Ignore unnecessary warnings thrown by Python
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import openpyxl

# %%
# Creates a new excel file with a default Sheet Name "Sheet" and save it in a variable "book"

book = openpyxl.Workbook()                     # Initialize the module
book_sheet = book['Sheet']                     # Opens the default "Sheet"
book_sheet.title = 'Renamed_Sheet'             # Renames the default Sheet as "Renamed_Sheet"

book.create_sheet('Sheet 1')                   # Creates a new sheet
book.create_sheet('Sheet 2')

book.save("Openpyxl\\New_File.xlsx")           # Saves the excel file

# %%
# Delete an existing sheet

book = openpyxl.load_workbook("Openpyxl\\New_File.xlsx")
print("Sheets available before delete: ", book.get_sheet_names())

sheet_to_delete = book.get_sheet_by_name('Renamed_Sheet')
book.remove_sheet(sheet_to_delete)
print("Sheets available after delete: ", book.get_sheet_names())

book.save("Openpyxl\\New_File.xlsx")
# Out:
# Sheets available before delete:  ['Renamed_Sheet', 'Sheet 1', 'Sheet 2']
# Sheets available after delete:  ['Sheet 1', 'Sheet 2']

# %%
# Load an existing Excel File and save it in a variable wb
# Provide path to the excel file or just the file name if it is saved in your current working directory

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")            
print(wb)                                              # Returns the file object but the content is encoded
# Out:
# <openpyxl.workbook.workbook.Workbook object at 0x00000196B33456A0>

# %%
# Extract the sheet names from the excel file and save them as a list in a variable: Sheet_Names

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")          # Create a file object for the excel file
Sheet_Names = wb.sheetnames                                   # Extract Sheet Names
print("List of Sheet Names in Excel File: ", Sheet_Names)
print(type(Sheet_Names))
# Out:
# List of Sheet Names in Excel File:  ['8th Gen NOP+BP 3D Maps', '8th Gen CR+WG 3D Maps', '7th Gen NOP+VGT 3D Maps', '7th Gen CR+WG 3D Maps', '8th Gen 2D Graphs', '7th Gen 2D Graphs', 'Monthly Budget', 'Sheet1', 'New_Sheet', 'New_Sheet1']
# <class 'list'>

# %%
# Search if a specific sheet by the name "8th Gen 2D Graphs" exists in the excel file

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")          # Create a file object for the excel file
Sheet_Names = wb.sheetnames                                   # Extract Sheet Names

Search_Item = "8th Gen 2D Graphs"          
if Search_Item in Sheet_Names:
    print("Sheet name exists")
else:
    print("Sheet name does not exist")
# Out:
# Sheet name exists

# %%
# Load contents of a specific sheet from the excel file in a variable that is encrypted. This can be decripted later

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item

print("\nContents of the specified sheet (Encrypted):", Data)
print("Data Type: ", type(Data))
# Out:
# Contents of the specified sheet (Encrypted): <Worksheet "8th Gen 2D Graphs">
# Data Type:  <class 'openpyxl.worksheet.worksheet.Worksheet'>

# %%
# Extract max number of rows and columns in the specific excel sheet:

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item
max_row = Data.max_row  
print("Number of Rows: ", max_row)  

max_column = Data.max_column  
print("\nNumber of Columns: ", max_column)
# Out:
# Number of Rows:  124
#
# Number of Columns:  3

# %%
# Extract contents of a specific column for example column "A":

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item
    
print("Printing Contents of Column A:")
for val in Data["A"]:
    if val.value is None:
        break                   # Comes out of the loop the moment it finds an empty cell
    print(val.value)
# Out:
# Printing Contents of Column A:
# mc_apres_select_map_y
# har_apres_select_map_y
# egd_ctemp_limit_pos_map_y
# ep_boost_temp_trq_red_map_y
# ep_egr_temp_trq_red_map_y
# mt_max_torque_eng_prot_map_y
# ep_cool_temp_trq_red_map_y
# ep_exhaust_temp_trq_red_map_y
# ep_oil_pres_lo_map_y
# ep_oil_temp_trq_red_map_y
# har_apres_select_map_y
# mc_air_inlet_cold_start_map_y
# mc_apres_select_map_y
# mc_coolant_cold_start_map_y
# mc_crnk_2_run_offset_map_y
# mt_max_torque_high_map_y
# sl_afr_min_trq_map_y
# trql_max_torque_cr_map_y
# trql_min_torque_temp_map_y

# %%
# Read values from a specific cell in a specific sheet:

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item
max_row = Data.max_row  
max_column = Data.max_column  

for i in range (max_row):
    for j in range (max_column):
        content = Data.cell(row=i+1, column=j+1).value     # Read content of a cell
        # Data.cell(row=i+1, column=j+1).value = 10        # Assign value to a cell
        print ("Content of Row No: ", i+1 , " & Column No: ", j+1 , " Is: ", content)
# Out:
# Content of Row No:  1  & Column No:  1  Is:  mc_apres_select_map_y
# Content of Row No:  1  & Column No:  2  Is:  2D graph
# Content of Row No:  1  & Column No:  3  Is:  mc_apres_select_map_y2D graph
# Content of Row No:  2  & Column No:  1  Is:  har_apres_select_map_y
# Content of Row No:  2  & Column No:  2  Is:  2D graph
# Content of Row No:  2  & Column No:  3  Is:  har_apres_select_map_y2D graph
# Content of Row No:  3  & Column No:  1  Is:  egd_ctemp_limit_pos_map_y
# Content of Row No:  3  & Column No:  2  Is:  None
# Content of Row No:  3  & Column No:  3  Is:  egd_ctemp_limit_pos_map_yNone
# Content of Row No:  4  & Column No:  1  Is:  ep_boost_temp_trq_red_map_y
# Content of Row No:  4  & Column No:  2  Is:  None
# Content of Row No:  4  & Column No:  3  Is:  ep_boost_temp_trq_red_map_yNone
# Content of Row No:  5  & Column No:  1  Is:  ep_egr_temp_trq_red_map_y
# Content of Row No:  5  & Column No:  2  Is:  None
# Content of Row No:  5  & Column No:  3  Is:  ep_egr_temp_trq_red_map_yNone
# Content of Row No:  6  & Column No:  1  Is:  mt_max_torque_eng_prot_map_y
# Content of Row No:  6  & Column No:  2  Is:  None
# Content of Row No:  6  & Column No:  3  Is:  mt_max_torque_eng_prot_map_yNone
# Content of Row No:  7  & Column No:  1  Is:  ep_cool_temp_trq_red_map_y
# Content of Row No:  7  & Column No:  2  Is:  None
# Content of Row No:  7  & Column No:  3  Is:  ep_cool_temp_trq_red_map_yNone
# Content of Row No:  8  & Column No:  1  Is:  ep_exhaust_temp_trq_red_map_y
# Content of Row No:  8  & Column No:  2  Is:  None
# Content of Row No:  8  & Column No:  3  Is:  ep_exhaust_temp_trq_red_map_yNone
# Content of Row No:  9  & Column No:  1  Is:  ep_oil_pres_lo_map_y
# Content of Row No:  9  & Column No:  2  Is:  None
# Content of Row No:  9  & Column No:  3  Is:  ep_oil_pres_lo_map_yNone
# Content of Row No:  10  & Column No:  1  Is:  ep_oil_temp_trq_red_map_y
# Content of Row No:  10  & Column No:  2  Is:  None
# Content of Row No:  10  & Column No:  3  Is:  ep_oil_temp_trq_red_map_yNone
# Content of Row No:  11  & Column No:  1  Is:  har_apres_select_map_y
# Content of Row No:  11  & Column No:  2  Is:  None
# Content of Row No:  11  & Column No:  3  Is:  har_apres_select_map_yNone
# Content of Row No:  12  & Column No:  1  Is:  mc_air_inlet_cold_start_map_y
# Content of Row No:  12  & Column No:  2  Is:  None
# Content of Row No:  12  & Column No:  3  Is:  mc_air_inlet_cold_start_map_yNone
# Content of Row No:  13  & Column No:  1  Is:  mc_apres_select_map_y
# Content of Row No:  13  & Column No:  2  Is:  None
# Content of Row No:  13  & Column No:  3  Is:  mc_apres_select_map_yNone
# Content of Row No:  14  & Column No:  1  Is:  mc_coolant_cold_start_map_y
# Content of Row No:  14  & Column No:  2  Is:  None
# Content of Row No:  14  & Column No:  3  Is:  mc_coolant_cold_start_map_yNone
# Content of Row No:  15  & Column No:  1  Is:  mc_crnk_2_run_offset_map_y
# Content of Row No:  15  & Column No:  2  Is:  None
# Content of Row No:  15  & Column No:  3  Is:  mc_crnk_2_run_offset_map_yNone
# Content of Row No:  16  & Column No:  1  Is:  mt_max_torque_high_map_y
# Content of Row No:  16  & Column No:  2  Is:  None
# Content of Row No:  16  & Column No:  3  Is:  mt_max_torque_high_map_yNone
# Content of Row No:  17  & Column No:  1  Is:  sl_afr_min_trq_map_y
# Content of Row No:  17  & Column No:  2  Is:  None
# Content of Row No:  17  & Column No:  3  Is:  sl_afr_min_trq_map_yNone
# Content of Row No:  18  & Column No:  1  Is:  trql_max_torque_cr_map_y
# Content of Row No:  18  & Column No:  2  Is:  None
# Content of Row No:  18  & Column No:  3  Is:  trql_max_torque_cr_map_yNone
# Content of Row No:  19  & Column No:  1  Is:  trql_min_torque_temp_map_y
# Content of Row No:  19  & Column No:  2  Is:  None
# Content of Row No:  19  & Column No:  3  Is:  trql_min_torque_temp_map_yNone
# Content of Row No:  20  & Column No:  1  Is:  None
# Content of Row No:  20  & Column No:  2  Is:  None
# Content of Row No:  20  & Column No:  3  Is:  None
# Content of Row No:  21  & Column No:  1  Is:  None
# Content of Row No:  21  & Column No:  2  Is:  None
# Content of Row No:  21  & Column No:  3  Is:  None
# Content of Row No:  22  & Column No:  1  Is:  None
# Content of Row No:  22  & Column No:  2  Is:  None
# Content of Row No:  22  & Column No:  3  Is:  None
# Content of Row No:  23  & Column No:  1  Is:  None
# Content of Row No:  23  & Column No:  2  Is:  None
# Content of Row No:  23  & Column No:  3  Is:  None
# Content of Row No:  24  & Column No:  1  Is:  None
# Content of Row No:  24  & Column No:  2  Is:  None
# Content of Row No:  24  & Column No:  3  Is:  None
# Content of Row No:  25  & Column No:  1  Is:  None
# Content of Row No:  25  & Column No:  2  Is:  None
# Content of Row No:  25  & Column No:  3  Is:  None
# Content of Row No:  26  & Column No:  1  Is:  None
# Content of Row No:  26  & Column No:  2  Is:  None
# Content of Row No:  26  & Column No:  3  Is:  None
# Content of Row No:  27  & Column No:  1  Is:  None
# Content of Row No:  27  & Column No:  2  Is:  None
# Content of Row No:  27  & Column No:  3  Is:  None
# Content of Row No:  28  & Column No:  1  Is:  None
# Content of Row No:  28  & Column No:  2  Is:  None
# Content of Row No:  28  & Column No:  3  Is:  None
# Content of Row No:  29  & Column No:  1  Is:  None
# Content of Row No:  29  & Column No:  2  Is:  None
# Content of Row No:  29  & Column No:  3  Is:  None
# Content of Row No:  30  & Column No:  1  Is:  None
# Content of Row No:  30  & Column No:  2  Is:  None
# Content of Row No:  30  & Column No:  3  Is:  None
# Content of Row No:  31  & Column No:  1  Is:  None
# Content of Row No:  31  & Column No:  2  Is:  None
# Content of Row No:  31  & Column No:  3  Is:  None
# Content of Row No:  32  & Column No:  1  Is:  None
# Content of Row No:  32  & Column No:  2  Is:  None
# Content of Row No:  32  & Column No:  3  Is:  None
# Content of Row No:  33  & Column No:  1  Is:  None
# Content of Row No:  33  & Column No:  2  Is:  None
# Content of Row No:  33  & Column No:  3  Is:  None
# Content of Row No:  34  & Column No:  1  Is:  None
# Content of Row No:  34  & Column No:  2  Is:  None
# Content of Row No:  34  & Column No:  3  Is:  None
# Content of Row No:  35  & Column No:  1  Is:  None
# Content of Row No:  35  & Column No:  2  Is:  None
# Content of Row No:  35  & Column No:  3  Is:  None
# Content of Row No:  36  & Column No:  1  Is:  None
# Content of Row No:  36  & Column No:  2  Is:  None
# Content of Row No:  36  & Column No:  3  Is:  None
# Content of Row No:  37  & Column No:  1  Is:  None
# Content of Row No:  37  & Column No:  2  Is:  None
# Content of Row No:  37  & Column No:  3  Is:  None
# Content of Row No:  38  & Column No:  1  Is:  None
# Content of Row No:  38  & Column No:  2  Is:  None
# Content of Row No:  38  & Column No:  3  Is:  None
# Content of Row No:  39  & Column No:  1  Is:  None
# Content of Row No:  39  & Column No:  2  Is:  None
# Content of Row No:  39  & Column No:  3  Is:  None
# Content of Row No:  40  & Column No:  1  Is:  None
# Content of Row No:  40  & Column No:  2  Is:  None
# Content of Row No:  40  & Column No:  3  Is:  None
# Content of Row No:  41  & Column No:  1  Is:  None
# Content of Row No:  41  & Column No:  2  Is:  None
# Content of Row No:  41  & Column No:  3  Is:  None
# Content of Row No:  42  & Column No:  1  Is:  None
# Content of Row No:  42  & Column No:  2  Is:  None
# Content of Row No:  42  & Column No:  3  Is:  None
# Content of Row No:  43  & Column No:  1  Is:  None
# Content of Row No:  43  & Column No:  2  Is:  None
# Content of Row No:  43  & Column No:  3  Is:  None
# Content of Row No:  44  & Column No:  1  Is:  None
# Content of Row No:  44  & Column No:  2  Is:  None
# Content of Row No:  44  & Column No:  3  Is:  None
# Content of Row No:  45  & Column No:  1  Is:  None
# Content of Row No:  45  & Column No:  2  Is:  None
# Content of Row No:  45  & Column No:  3  Is:  None
# Content of Row No:  46  & Column No:  1  Is:  None
# Content of Row No:  46  & Column No:  2  Is:  None
# Content of Row No:  46  & Column No:  3  Is:  None
# Content of Row No:  47  & Column No:  1  Is:  None
# Content of Row No:  47  & Column No:  2  Is:  None
# Content of Row No:  47  & Column No:  3  Is:  None
# Content of Row No:  48  & Column No:  1  Is:  None
# Content of Row No:  48  & Column No:  2  Is:  None
# Content of Row No:  48  & Column No:  3  Is:  None
# Content of Row No:  49  & Column No:  1  Is:  None
# Content of Row No:  49  & Column No:  2  Is:  None
# Content of Row No:  49  & Column No:  3  Is:  None
# Content of Row No:  50  & Column No:  1  Is:  None
# Content of Row No:  50  & Column No:  2  Is:  None
# Content of Row No:  50  & Column No:  3  Is:  None
# Content of Row No:  51  & Column No:  1  Is:  None
# Content of Row No:  51  & Column No:  2  Is:  None
# Content of Row No:  51  & Column No:  3  Is:  None
# Content of Row No:  52  & Column No:  1  Is:  None
# Content of Row No:  52  & Column No:  2  Is:  None
# Content of Row No:  52  & Column No:  3  Is:  None
# Content of Row No:  53  & Column No:  1  Is:  None
# Content of Row No:  53  & Column No:  2  Is:  None
# Content of Row No:  53  & Column No:  3  Is:  None
# Content of Row No:  54  & Column No:  1  Is:  None
# Content of Row No:  54  & Column No:  2  Is:  None
# Content of Row No:  54  & Column No:  3  Is:  None
# Content of Row No:  55  & Column No:  1  Is:  None
# Content of Row No:  55  & Column No:  2  Is:  None
# Content of Row No:  55  & Column No:  3  Is:  None
# Content of Row No:  56  & Column No:  1  Is:  None
# Content of Row No:  56  & Column No:  2  Is:  None
# Content of Row No:  56  & Column No:  3  Is:  None
# Content of Row No:  57  & Column No:  1  Is:  None
# Content of Row No:  57  & Column No:  2  Is:  None
# Content of Row No:  57  & Column No:  3  Is:  None
# Content of Row No:  58  & Column No:  1  Is:  None
# Content of Row No:  58  & Column No:  2  Is:  None
# Content of Row No:  58  & Column No:  3  Is:  None
# Content of Row No:  59  & Column No:  1  Is:  None
# Content of Row No:  59  & Column No:  2  Is:  None
# Content of Row No:  59  & Column No:  3  Is:  None
# Content of Row No:  60  & Column No:  1  Is:  None
# Content of Row No:  60  & Column No:  2  Is:  None
# Content of Row No:  60  & Column No:  3  Is:  None
# Content of Row No:  61  & Column No:  1  Is:  None
# Content of Row No:  61  & Column No:  2  Is:  None
# Content of Row No:  61  & Column No:  3  Is:  None
# Content of Row No:  62  & Column No:  1  Is:  None
# Content of Row No:  62  & Column No:  2  Is:  None
# Content of Row No:  62  & Column No:  3  Is:  None
# Content of Row No:  63  & Column No:  1  Is:  None
# Content of Row No:  63  & Column No:  2  Is:  None
# Content of Row No:  63  & Column No:  3  Is:  None
# Content of Row No:  64  & Column No:  1  Is:  None
# Content of Row No:  64  & Column No:  2  Is:  None
# Content of Row No:  64  & Column No:  3  Is:  None
# Content of Row No:  65  & Column No:  1  Is:  None
# Content of Row No:  65  & Column No:  2  Is:  None
# Content of Row No:  65  & Column No:  3  Is:  None
# Content of Row No:  66  & Column No:  1  Is:  None
# Content of Row No:  66  & Column No:  2  Is:  None
# Content of Row No:  66  & Column No:  3  Is:  None
# Content of Row No:  67  & Column No:  1  Is:  None
# Content of Row No:  67  & Column No:  2  Is:  None
# Content of Row No:  67  & Column No:  3  Is:  None
# Content of Row No:  68  & Column No:  1  Is:  None
# Content of Row No:  68  & Column No:  2  Is:  None
# Content of Row No:  68  & Column No:  3  Is:  None
# Content of Row No:  69  & Column No:  1  Is:  None
# Content of Row No:  69  & Column No:  2  Is:  None
# Content of Row No:  69  & Column No:  3  Is:  None
# Content of Row No:  70  & Column No:  1  Is:  None
# Content of Row No:  70  & Column No:  2  Is:  None
# Content of Row No:  70  & Column No:  3  Is:  None
# Content of Row No:  71  & Column No:  1  Is:  None
# Content of Row No:  71  & Column No:  2  Is:  None
# Content of Row No:  71  & Column No:  3  Is:  None
# Content of Row No:  72  & Column No:  1  Is:  None
# Content of Row No:  72  & Column No:  2  Is:  None
# Content of Row No:  72  & Column No:  3  Is:  None
# Content of Row No:  73  & Column No:  1  Is:  None
# Content of Row No:  73  & Column No:  2  Is:  None
# Content of Row No:  73  & Column No:  3  Is:  None
# Content of Row No:  74  & Column No:  1  Is:  None
# Content of Row No:  74  & Column No:  2  Is:  None
# Content of Row No:  74  & Column No:  3  Is:  None
# Content of Row No:  75  & Column No:  1  Is:  None
# Content of Row No:  75  & Column No:  2  Is:  None
# Content of Row No:  75  & Column No:  3  Is:  None
# Content of Row No:  76  & Column No:  1  Is:  None
# Content of Row No:  76  & Column No:  2  Is:  None
# Content of Row No:  76  & Column No:  3  Is:  None
# Content of Row No:  77  & Column No:  1  Is:  None
# Content of Row No:  77  & Column No:  2  Is:  None
# Content of Row No:  77  & Column No:  3  Is:  None
# Content of Row No:  78  & Column No:  1  Is:  None
# Content of Row No:  78  & Column No:  2  Is:  None
# Content of Row No:  78  & Column No:  3  Is:  None
# Content of Row No:  79  & Column No:  1  Is:  None
# Content of Row No:  79  & Column No:  2  Is:  None
# Content of Row No:  79  & Column No:  3  Is:  None
# Content of Row No:  80  & Column No:  1  Is:  None
# Content of Row No:  80  & Column No:  2  Is:  None
# Content of Row No:  80  & Column No:  3  Is:  None
# Content of Row No:  81  & Column No:  1  Is:  None
# Content of Row No:  81  & Column No:  2  Is:  None
# Content of Row No:  81  & Column No:  3  Is:  None
# Content of Row No:  82  & Column No:  1  Is:  None
# Content of Row No:  82  & Column No:  2  Is:  None
# Content of Row No:  82  & Column No:  3  Is:  None
# Content of Row No:  83  & Column No:  1  Is:  None
# Content of Row No:  83  & Column No:  2  Is:  None
# Content of Row No:  83  & Column No:  3  Is:  None
# Content of Row No:  84  & Column No:  1  Is:  None
# Content of Row No:  84  & Column No:  2  Is:  None
# Content of Row No:  84  & Column No:  3  Is:  None
# Content of Row No:  85  & Column No:  1  Is:  None
# Content of Row No:  85  & Column No:  2  Is:  None
# Content of Row No:  85  & Column No:  3  Is:  None
# Content of Row No:  86  & Column No:  1  Is:  None
# Content of Row No:  86  & Column No:  2  Is:  None
# Content of Row No:  86  & Column No:  3  Is:  None
# Content of Row No:  87  & Column No:  1  Is:  None
# Content of Row No:  87  & Column No:  2  Is:  None
# Content of Row No:  87  & Column No:  3  Is:  None
# Content of Row No:  88  & Column No:  1  Is:  None
# Content of Row No:  88  & Column No:  2  Is:  None
# Content of Row No:  88  & Column No:  3  Is:  None
# Content of Row No:  89  & Column No:  1  Is:  None
# Content of Row No:  89  & Column No:  2  Is:  None
# Content of Row No:  89  & Column No:  3  Is:  None
# Content of Row No:  90  & Column No:  1  Is:  None
# Content of Row No:  90  & Column No:  2  Is:  None
# Content of Row No:  90  & Column No:  3  Is:  None
# Content of Row No:  91  & Column No:  1  Is:  None
# Content of Row No:  91  & Column No:  2  Is:  None
# Content of Row No:  91  & Column No:  3  Is:  None
# Content of Row No:  92  & Column No:  1  Is:  None
# Content of Row No:  92  & Column No:  2  Is:  None
# Content of Row No:  92  & Column No:  3  Is:  None
# Content of Row No:  93  & Column No:  1  Is:  None
# Content of Row No:  93  & Column No:  2  Is:  None
# Content of Row No:  93  & Column No:  3  Is:  None
# Content of Row No:  94  & Column No:  1  Is:  None
# Content of Row No:  94  & Column No:  2  Is:  None
# Content of Row No:  94  & Column No:  3  Is:  None
# Content of Row No:  95  & Column No:  1  Is:  None
# Content of Row No:  95  & Column No:  2  Is:  None
# Content of Row No:  95  & Column No:  3  Is:  None
# Content of Row No:  96  & Column No:  1  Is:  None
# Content of Row No:  96  & Column No:  2  Is:  None
# Content of Row No:  96  & Column No:  3  Is:  None
# Content of Row No:  97  & Column No:  1  Is:  None
# Content of Row No:  97  & Column No:  2  Is:  None
# Content of Row No:  97  & Column No:  3  Is:  None
# Content of Row No:  98  & Column No:  1  Is:  None
# Content of Row No:  98  & Column No:  2  Is:  None
# Content of Row No:  98  & Column No:  3  Is:  None
# Content of Row No:  99  & Column No:  1  Is:  None
# Content of Row No:  99  & Column No:  2  Is:  None
# Content of Row No:  99  & Column No:  3  Is:  None
# Content of Row No:  100  & Column No:  1  Is:  None
# Content of Row No:  100  & Column No:  2  Is:  None
# Content of Row No:  100  & Column No:  3  Is:  None
# Content of Row No:  101  & Column No:  1  Is:  None
# Content of Row No:  101  & Column No:  2  Is:  None
# Content of Row No:  101  & Column No:  3  Is:  None
# Content of Row No:  102  & Column No:  1  Is:  None
# Content of Row No:  102  & Column No:  2  Is:  None
# Content of Row No:  102  & Column No:  3  Is:  None
# Content of Row No:  103  & Column No:  1  Is:  None
# Content of Row No:  103  & Column No:  2  Is:  None
# Content of Row No:  103  & Column No:  3  Is:  None
# Content of Row No:  104  & Column No:  1  Is:  None
# Content of Row No:  104  & Column No:  2  Is:  None
# Content of Row No:  104  & Column No:  3  Is:  None
# Content of Row No:  105  & Column No:  1  Is:  None
# Content of Row No:  105  & Column No:  2  Is:  None
# Content of Row No:  105  & Column No:  3  Is:  None
# Content of Row No:  106  & Column No:  1  Is:  None
# Content of Row No:  106  & Column No:  2  Is:  None
# Content of Row No:  106  & Column No:  3  Is:  None
# Content of Row No:  107  & Column No:  1  Is:  None
# Content of Row No:  107  & Column No:  2  Is:  None
# Content of Row No:  107  & Column No:  3  Is:  None
# Content of Row No:  108  & Column No:  1  Is:  None
# Content of Row No:  108  & Column No:  2  Is:  None
# Content of Row No:  108  & Column No:  3  Is:  None
# Content of Row No:  109  & Column No:  1  Is:  None
# Content of Row No:  109  & Column No:  2  Is:  None
# Content of Row No:  109  & Column No:  3  Is:  None
# Content of Row No:  110  & Column No:  1  Is:  None
# Content of Row No:  110  & Column No:  2  Is:  None
# Content of Row No:  110  & Column No:  3  Is:  None
# Content of Row No:  111  & Column No:  1  Is:  None
# Content of Row No:  111  & Column No:  2  Is:  None
# Content of Row No:  111  & Column No:  3  Is:  None
# Content of Row No:  112  & Column No:  1  Is:  None
# Content of Row No:  112  & Column No:  2  Is:  None
# Content of Row No:  112  & Column No:  3  Is:  None
# Content of Row No:  113  & Column No:  1  Is:  None
# Content of Row No:  113  & Column No:  2  Is:  None
# Content of Row No:  113  & Column No:  3  Is:  None
# Content of Row No:  114  & Column No:  1  Is:  None
# Content of Row No:  114  & Column No:  2  Is:  None
# Content of Row No:  114  & Column No:  3  Is:  None
# Content of Row No:  115  & Column No:  1  Is:  None
# Content of Row No:  115  & Column No:  2  Is:  None
# Content of Row No:  115  & Column No:  3  Is:  None
# Content of Row No:  116  & Column No:  1  Is:  None
# Content of Row No:  116  & Column No:  2  Is:  None
# Content of Row No:  116  & Column No:  3  Is:  None
# Content of Row No:  117  & Column No:  1  Is:  None
# Content of Row No:  117  & Column No:  2  Is:  None
# Content of Row No:  117  & Column No:  3  Is:  None
# Content of Row No:  118  & Column No:  1  Is:  None
# Content of Row No:  118  & Column No:  2  Is:  None
# Content of Row No:  118  & Column No:  3  Is:  None
# Content of Row No:  119  & Column No:  1  Is:  None
# Content of Row No:  119  & Column No:  2  Is:  None
# Content of Row No:  119  & Column No:  3  Is:  None
# Content of Row No:  120  & Column No:  1  Is:  None
# Content of Row No:  120  & Column No:  2  Is:  None
# Content of Row No:  120  & Column No:  3  Is:  None
# Content of Row No:  121  & Column No:  1  Is:  None
# Content of Row No:  121  & Column No:  2  Is:  None
# Content of Row No:  121  & Column No:  3  Is:  None
# Content of Row No:  122  & Column No:  1  Is:  None
# Content of Row No:  122  & Column No:  2  Is:  None
# Content of Row No:  122  & Column No:  3  Is:  None
# Content of Row No:  123  & Column No:  1  Is:  None
# Content of Row No:  123  & Column No:  2  Is:  None
# Content of Row No:  123  & Column No:  3  Is:  None
# Content of Row No:  124  & Column No:  1  Is:  None
# Content of Row No:  124  & Column No:  2  Is:  None
# Content of Row No:  124  & Column No:  3  Is:  None

# %%
# Write values to a specific cell in a specific sheet

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item
max_row = Data.max_row  
max_column = Data.max_column 

for i in range (max_row):    
    Data.cell(row=i+1, column=3).value = "Cell No. " + str(i+1) + " , 3"
    print ("Content Written to Column 3, row ", i+1)
wb.save("Openpyxl\\Sample.xlsx")
# Out:
# Content Written to Column 3, row  1
# Content Written to Column 3, row  2
# Content Written to Column 3, row  3
# Content Written to Column 3, row  4
# Content Written to Column 3, row  5
# Content Written to Column 3, row  6
# Content Written to Column 3, row  7
# Content Written to Column 3, row  8
# Content Written to Column 3, row  9
# Content Written to Column 3, row  10
# Content Written to Column 3, row  11
# Content Written to Column 3, row  12
# Content Written to Column 3, row  13
# Content Written to Column 3, row  14
# Content Written to Column 3, row  15
# Content Written to Column 3, row  16
# Content Written to Column 3, row  17
# Content Written to Column 3, row  18
# Content Written to Column 3, row  19
# Content Written to Column 3, row  20
# Content Written to Column 3, row  21
# Content Written to Column 3, row  22
# Content Written to Column 3, row  23
# Content Written to Column 3, row  24
# Content Written to Column 3, row  25
# Content Written to Column 3, row  26
# Content Written to Column 3, row  27
# Content Written to Column 3, row  28
# Content Written to Column 3, row  29
# Content Written to Column 3, row  30
# Content Written to Column 3, row  31
# Content Written to Column 3, row  32
# Content Written to Column 3, row  33
# Content Written to Column 3, row  34
# Content Written to Column 3, row  35
# Content Written to Column 3, row  36
# Content Written to Column 3, row  37
# Content Written to Column 3, row  38
# Content Written to Column 3, row  39
# Content Written to Column 3, row  40
# Content Written to Column 3, row  41
# Content Written to Column 3, row  42
# Content Written to Column 3, row  43
# Content Written to Column 3, row  44
# Content Written to Column 3, row  45
# Content Written to Column 3, row  46
# Content Written to Column 3, row  47
# Content Written to Column 3, row  48
# Content Written to Column 3, row  49
# Content Written to Column 3, row  50
# Content Written to Column 3, row  51
# Content Written to Column 3, row  52
# Content Written to Column 3, row  53
# Content Written to Column 3, row  54
# Content Written to Column 3, row  55
# Content Written to Column 3, row  56
# Content Written to Column 3, row  57
# Content Written to Column 3, row  58
# Content Written to Column 3, row  59
# Content Written to Column 3, row  60
# Content Written to Column 3, row  61
# Content Written to Column 3, row  62
# Content Written to Column 3, row  63
# Content Written to Column 3, row  64
# Content Written to Column 3, row  65
# Content Written to Column 3, row  66
# Content Written to Column 3, row  67
# Content Written to Column 3, row  68
# Content Written to Column 3, row  69
# Content Written to Column 3, row  70
# Content Written to Column 3, row  71
# Content Written to Column 3, row  72
# Content Written to Column 3, row  73
# Content Written to Column 3, row  74
# Content Written to Column 3, row  75
# Content Written to Column 3, row  76
# Content Written to Column 3, row  77
# Content Written to Column 3, row  78
# Content Written to Column 3, row  79
# Content Written to Column 3, row  80
# Content Written to Column 3, row  81
# Content Written to Column 3, row  82
# Content Written to Column 3, row  83
# Content Written to Column 3, row  84
# Content Written to Column 3, row  85
# Content Written to Column 3, row  86
# Content Written to Column 3, row  87
# Content Written to Column 3, row  88
# Content Written to Column 3, row  89
# Content Written to Column 3, row  90
# Content Written to Column 3, row  91
# Content Written to Column 3, row  92
# Content Written to Column 3, row  93
# Content Written to Column 3, row  94
# Content Written to Column 3, row  95
# Content Written to Column 3, row  96
# Content Written to Column 3, row  97
# Content Written to Column 3, row  98
# Content Written to Column 3, row  99
# Content Written to Column 3, row  100
# Content Written to Column 3, row  101
# Content Written to Column 3, row  102
# Content Written to Column 3, row  103
# Content Written to Column 3, row  104
# Content Written to Column 3, row  105
# Content Written to Column 3, row  106
# Content Written to Column 3, row  107
# Content Written to Column 3, row  108
# Content Written to Column 3, row  109
# Content Written to Column 3, row  110
# Content Written to Column 3, row  111
# Content Written to Column 3, row  112
# Content Written to Column 3, row  113
# Content Written to Column 3, row  114
# Content Written to Column 3, row  115
# Content Written to Column 3, row  116
# Content Written to Column 3, row  117
# Content Written to Column 3, row  118
# Content Written to Column 3, row  119
# Content Written to Column 3, row  120
# Content Written to Column 3, row  121
# Content Written to Column 3, row  122
# Content Written to Column 3, row  123
# Content Written to Column 3, row  124

# %%
# Delete values in a specific cell in a specific sheet

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item
max_row = Data.max_row  
max_column = Data.max_column 

for i in range (max_row):    
    Data.cell(row=i+1, column=3).value = ""
    print ("Content of Column 3, row ", i+1, " Deleted")
wb.save("Openpyxl\\Sample.xlsx")
# Out:
# Content of Column 3, row  1  Deleted
# Content of Column 3, row  2  Deleted
# Content of Column 3, row  3  Deleted
# Content of Column 3, row  4  Deleted
# Content of Column 3, row  5  Deleted
# Content of Column 3, row  6  Deleted
# Content of Column 3, row  7  Deleted
# Content of Column 3, row  8  Deleted
# Content of Column 3, row  9  Deleted
# Content of Column 3, row  10  Deleted
# Content of Column 3, row  11  Deleted
# Content of Column 3, row  12  Deleted
# Content of Column 3, row  13  Deleted
# Content of Column 3, row  14  Deleted
# Content of Column 3, row  15  Deleted
# Content of Column 3, row  16  Deleted
# Content of Column 3, row  17  Deleted
# Content of Column 3, row  18  Deleted
# Content of Column 3, row  19  Deleted
# Content of Column 3, row  20  Deleted
# Content of Column 3, row  21  Deleted
# Content of Column 3, row  22  Deleted
# Content of Column 3, row  23  Deleted
# Content of Column 3, row  24  Deleted
# Content of Column 3, row  25  Deleted
# Content of Column 3, row  26  Deleted
# Content of Column 3, row  27  Deleted
# Content of Column 3, row  28  Deleted
# Content of Column 3, row  29  Deleted
# Content of Column 3, row  30  Deleted
# Content of Column 3, row  31  Deleted
# Content of Column 3, row  32  Deleted
# Content of Column 3, row  33  Deleted
# Content of Column 3, row  34  Deleted
# Content of Column 3, row  35  Deleted
# Content of Column 3, row  36  Deleted
# Content of Column 3, row  37  Deleted
# Content of Column 3, row  38  Deleted
# Content of Column 3, row  39  Deleted
# Content of Column 3, row  40  Deleted
# Content of Column 3, row  41  Deleted
# Content of Column 3, row  42  Deleted
# Content of Column 3, row  43  Deleted
# Content of Column 3, row  44  Deleted
# Content of Column 3, row  45  Deleted
# Content of Column 3, row  46  Deleted
# Content of Column 3, row  47  Deleted
# Content of Column 3, row  48  Deleted
# Content of Column 3, row  49  Deleted
# Content of Column 3, row  50  Deleted
# Content of Column 3, row  51  Deleted
# Content of Column 3, row  52  Deleted
# Content of Column 3, row  53  Deleted
# Content of Column 3, row  54  Deleted
# Content of Column 3, row  55  Deleted
# Content of Column 3, row  56  Deleted
# Content of Column 3, row  57  Deleted
# Content of Column 3, row  58  Deleted
# Content of Column 3, row  59  Deleted
# Content of Column 3, row  60  Deleted
# Content of Column 3, row  61  Deleted
# Content of Column 3, row  62  Deleted
# Content of Column 3, row  63  Deleted
# Content of Column 3, row  64  Deleted
# Content of Column 3, row  65  Deleted
# Content of Column 3, row  66  Deleted
# Content of Column 3, row  67  Deleted
# Content of Column 3, row  68  Deleted
# Content of Column 3, row  69  Deleted
# Content of Column 3, row  70  Deleted
# Content of Column 3, row  71  Deleted
# Content of Column 3, row  72  Deleted
# Content of Column 3, row  73  Deleted
# Content of Column 3, row  74  Deleted
# Content of Column 3, row  75  Deleted
# Content of Column 3, row  76  Deleted
# Content of Column 3, row  77  Deleted
# Content of Column 3, row  78  Deleted
# Content of Column 3, row  79  Deleted
# Content of Column 3, row  80  Deleted
# Content of Column 3, row  81  Deleted
# Content of Column 3, row  82  Deleted
# Content of Column 3, row  83  Deleted
# Content of Column 3, row  84  Deleted
# Content of Column 3, row  85  Deleted
# Content of Column 3, row  86  Deleted
# Content of Column 3, row  87  Deleted
# Content of Column 3, row  88  Deleted
# Content of Column 3, row  89  Deleted
# Content of Column 3, row  90  Deleted
# Content of Column 3, row  91  Deleted
# Content of Column 3, row  92  Deleted
# Content of Column 3, row  93  Deleted
# Content of Column 3, row  94  Deleted
# Content of Column 3, row  95  Deleted
# Content of Column 3, row  96  Deleted
# Content of Column 3, row  97  Deleted
# Content of Column 3, row  98  Deleted
# Content of Column 3, row  99  Deleted
# Content of Column 3, row  100  Deleted
# Content of Column 3, row  101  Deleted
# Content of Column 3, row  102  Deleted
# Content of Column 3, row  103  Deleted
# Content of Column 3, row  104  Deleted
# Content of Column 3, row  105  Deleted
# Content of Column 3, row  106  Deleted
# Content of Column 3, row  107  Deleted
# Content of Column 3, row  108  Deleted
# Content of Column 3, row  109  Deleted
# Content of Column 3, row  110  Deleted
# Content of Column 3, row  111  Deleted
# Content of Column 3, row  112  Deleted
# Content of Column 3, row  113  Deleted
# Content of Column 3, row  114  Deleted
# Content of Column 3, row  115  Deleted
# Content of Column 3, row  116  Deleted
# Content of Column 3, row  117  Deleted
# Content of Column 3, row  118  Deleted
# Content of Column 3, row  119  Deleted
# Content of Column 3, row  120  Deleted
# Content of Column 3, row  121  Deleted
# Content of Column 3, row  122  Deleted
# Content of Column 3, row  123  Deleted
# Content of Column 3, row  124  Deleted

# %%
# Modify values to a specific cell in a specific sheet

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item
max_row = Data.max_row  
max_column = Data.max_column 

for i in range (max_row):    
    if Data.cell(row=i+1, column=1).value != None:                                         # Check if the cell is not empty
        Data.cell(row=i+1, column=1).value = Data.cell(row=i+1, column=1).value.lower()    # To convert to Lower Case
        Data.cell(row=i+1, column=3).value = str(Data.cell(row=i+1, column=1).value) + str(Data.cell(row=i+1, column=2).value)
        print ("Content of Column 1, row ", i+1, " changed to Lower Case")
wb.save("Openpyxl\\Sample.xlsx")
# Out:
# Content of Column 1, row  1  changed to Lower Case
# Content of Column 1, row  2  changed to Lower Case
# Content of Column 1, row  3  changed to Lower Case
# Content of Column 1, row  4  changed to Lower Case
# Content of Column 1, row  5  changed to Lower Case
# Content of Column 1, row  6  changed to Lower Case
# Content of Column 1, row  7  changed to Lower Case
# Content of Column 1, row  8  changed to Lower Case
# Content of Column 1, row  9  changed to Lower Case
# Content of Column 1, row  10  changed to Lower Case
# Content of Column 1, row  11  changed to Lower Case
# Content of Column 1, row  12  changed to Lower Case
# Content of Column 1, row  13  changed to Lower Case
# Content of Column 1, row  14  changed to Lower Case
# Content of Column 1, row  15  changed to Lower Case
# Content of Column 1, row  16  changed to Lower Case
# Content of Column 1, row  17  changed to Lower Case
# Content of Column 1, row  18  changed to Lower Case
# Content of Column 1, row  19  changed to Lower Case

# %%
# Add a new Worksheet and save a Transposed Matrix

wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Sheet_Names = wb.sheetnames                            # Extract Sheet Names
Search_Item = "8th Gen 2D Graphs"                      # Name of the worksheet that you wish to search in the excel file
                                                       # Search_Item is a variable that contains the Sheet Name as a string
Data = wb[Search_Item]                                 # Data is a variable that contains the contents of the sheet 
                                                       # specified by the variable Search_Item
max_row = Data.max_row  
max_column = Data.max_column 

wb.create_sheet("New_Sheet")                     # Create a new sheet in the same excel file to save transposed matrix
Data2 = wb["New_Sheet"]                          # Load the contents of the new sheet in a new variable

for i in range (max_row):
    for j in range (max_column):
        Data2.cell(row=j+1, column=i+1).value = Data.cell(row=i+1, column=j+1).value    # Transpose formula: value(row,column) = value(column,row)
print ('Successfully Transposed Matrix and saved it in "New_Sheet"')
wb.save("Openpyxl\\Sample.xlsx")
# Out:
# Successfully Transposed Matrix and saved it in "New_Sheet"

# %% [markdown]
# # Insert / Delete Rows / Columns

# %%
# this statement inserts a column before column 2
# Data.insert_cols(2)

# this statement inserts a row before row 2
# Data.insert_rows(2)

# for single row deletion
# Data.delete_rows(rownum) 

# for multiple row deletion
# Data.delete_rows(firstrow, numberofrows) 

# for single column deletion
# Data.delete_cols(colnum) 

# for multiple columns deletion
# Data.delete_cols(firstcol, numberofcols)

# %% [markdown]
# # Custom Formatting Excel Workbook

# %% [markdown]
# # Pattern & Gradient Fill

# %%
from openpyxl.styles import PatternFill, GradientFill

# %%
wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Data = wb['Monthly Budget']                            # Data is a variable that contains the contents of the sheet specified 

for c in Data['A5:B5'][0]:
    c.fill = PatternFill('solid', fgColor = 'F2F2F2')  
    
for c in Data['A14:B14'][0]:
    c.fill = PatternFill('gray0625')
    
Data['A17'].fill = GradientFill('linear', stop = ('85E4F7','4617F1'))
Data['A18'].fill = GradientFill('path', stop = ('85E4F7','4617F1'))
Data['A19'].fill = GradientFill('linear', stop = ('85E4F7','4617F1'))
    
wb.save("Openpyxl\\Sample.xlsx")

# %%
# For color codes, refer the link: https://openpyxl.readthedocs.io/en/stable/styles.html
# To create your own colors, refer this link: https://www.mathsisfun.com/hexadecimal-decimal-colors.html

# %% [markdown]
# # Borderlines

# %%
from openpyxl.styles import Border, Side

# %%
wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Data = wb['Monthly Budget']                            # Data is a variable that contains the contents of the sheet specified 

# Define the type of border, it's color and thickness:

double  = Side(border_style = "double", color = "4617F1")
thin    = Side(border_style = "thin"  , color = "4617F1")
regular = Side(border_style = "medium", color = "000000")

no_left_side  = Border(top = regular, bottom = regular, right = regular)
no_right_side = Border(top = regular, bottom = regular, left  = regular)
box           = Border(top = double , bottom = double , left  = double, right = double)

for c in Data['A1:A5'] + Data['A8:A14'] + Data['A17:A19']:
    c[0].border = no_left_side
    
for c in Data['B1:B5'] + Data['B8:B14'] + Data['B17:B19']:
    c[0].border = no_right_side
    
for c in Data['B22:B25']:
    c[0].border = box
    
wb.save("Openpyxl\\Sample.xlsx")

# %% [markdown]
# # Text Alignment

# %%
from openpyxl.styles import Alignment

# %%
wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Data = wb['Monthly Budget']                            # Data is a variable that contains the contents of the sheet specified 

center_align = Alignment(horizontal='center', vertical='center')

for c in Data['A1:A19'] + Data['B1:B25']:
    c[0].alignment = center_align

# for c in Data['B1:B25']:
#     c[0].alignment = center_align

wb.save("Openpyxl\\Sample.xlsx")

# %% [markdown]
# # Fonts and Styles

# %%
from openpyxl.styles import Font

# %%
wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Data = wb['Monthly Budget']                            # Data is a variable that contains the contents of the sheet specified 

Data['D1'].font = Font(name= 'Calibri',
                       size=40,
                       bold=True,
                       italic=False,
                       strike=False,
                       underline='none',
                       color='FF0000'
                       )

wb.save("Openpyxl\\Sample.xlsx")

# %% [markdown]
# # Copying Fonts

# %%
from copy import copy
from openpyxl.styles import Font

# %%
wb = openpyxl.load_workbook("Openpyxl\\Sample.xlsx")   # Create a file object for the excel file
Data = wb['Monthly Budget']                            # Data is a variable that contains the contents of the sheet specified 

Data['D3'].font = Font(bold=True, size = 14)     
Data['D1'].font = copy(Data['D3'].font)                    # Copy the font of cell D3 to cell D1

wb.save("Openpyxl\\Sample.xlsx")

# %%
# Detailed Documentation on openpyxl formatting: https://pythoninoffice.com/python-excel-number-format/
